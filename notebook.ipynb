# %%
import pandas as pd

df = pd.read_csv("./source/books.csv")

# %%
df.columns
# Out:
# Index(['Title', 'Author', 'Genre', 'Height', 'Publisher'], dtype='str')

# %%
df[["Title", "Genre", "Author",]]
# Out:
#                             Title              Genre              Author
# 0        Fundamentals of Wavelets  signal_processing    Goswami, Jaideva
# 1                      Data Smart       data_science       Foreman, John
# 2        God Created the Integers        mathematics    Hawking, Stephen
# 3               Superfreakonomics          economics     Dubner, Stephen
# 4                     Orientalism            history        Said, Edward
# ..                            ...                ...                 ...
# 206      Structure and Randomness        mathematics        Tao, Terence
# 207  Image Processing with MATLAB  signal_processing       Eddins, Steve
# 208                   Animal Farm            fiction      Orwell, George
# 209                    Idiot, The            fiction  Dostoevsky, Fyodor
# 210            Christmas Carol, A            fiction    Dickens, Charles
#
# [211 rows x 3 columns]

# %%
df.iloc[4][["Title", "Genre"]]
# Out:
# Title    Orientalism
# Genre        history
# Name: 4, dtype: object

# %%
df.head()
# Out:
#                       Title            Author              Genre  Height  \
# 0  Fundamentals of Wavelets  Goswami, Jaideva  signal_processing     228
# 1                Data Smart     Foreman, John       data_science     235
# 2  God Created the Integers  Hawking, Stephen        mathematics     197
# 3         Superfreakonomics   Dubner, Stephen          economics     179
# 4               Orientalism      Said, Edward            history     197
#
#        Publisher
# 0          Wiley
# 1          Wiley
# 2        Penguin
# 3  HarperCollins
# 4        Penguin

# %%
df[(df["Publisher"] == "Penguin") & (df["Genre"] == "history")]
# Out:
#                                Title              Author    Genre  Height  \
# 4                        Orientalism        Said, Edward  history     197
# 14                 Age of Wrath, The      Eraly, Abraham  history     238
# 74                  Last Mughal, The  Dalrymple, William  history     199
# 82  India from Midnight to Milennium     Tharoor, Shashi  history     198
#
#    Publisher
# 4    Penguin
# 14   Penguin
# 74   Penguin
# 82   Penguin

# %%
df[(df["Publisher"] == "Penguin") | (df["Publisher"] == "mathematics")]
# Out:
#                                  Title               Author         Genre  \
# 2             God Created the Integers     Hawking, Stephen   mathematics
# 4                          Orientalism         Said, Edward       history
# 7                 Drunkard's Walk, The    Mlodinow, Leonard       science
# 9    How to Think Like Sherlock Holmes     Konnikova, Maria    psychology
# 14                   Age of Wrath, The       Eraly, Abraham       history
# 18                New Machiavelli, The         Wells, H. G.       fiction
# 19                Physics & Philosophy   Heisenberg, Werner       science
# 23           Signal and the Noise, The         Silver, Nate  data_science
# 26       Beautiful and the Damned, The      Deb, Siddhartha    nonfiction
# 27                       Outsider, The        Camus, Albert       fiction
# 33                 Tao of Physics, The       Capra, Fritjof       science
# 39             Return of the Primitive            Rand, Ayn    philosophy
# ...

# %%
df[~df["Publisher"].isin(["Wiley", "HarperCollins"])]
# Out:
#                                           Title              Author  \
# 2                      God Created the Integers    Hawking, Stephen
# 4                                   Orientalism        Said, Edward
# 5    Nature of Statistical Learning Theory, The    Vapnik, Vladimir
# 6              Integration of the Indian States          Menon, V P
# 7                          Drunkard's Walk, The   Mlodinow, Leonard
# ..                                          ...                 ...
# 206                    Structure and Randomness        Tao, Terence
# 207                Image Processing with MATLAB       Eddins, Steve
# 208                                 Animal Farm      Orwell, George
# 209                                  Idiot, The  Dostoevsky, Fyodor
# 210                          Christmas Carol, A    Dickens, Charles
#
#                  Genre  Height         Publisher
# 2          mathematics     197           Penguin
# 4              history     197           Penguin
# ...

# %%
df.loc[df["Title"] == "Idiot, The", "Publisher"] = "Penguin"

# %%
#CLEANING DATA
df[~df["Publisher"].isin(["Wiley", "HarperCollins"])]
# Out:
#                                           Title              Author  \
# 2                      God Created the Integers    Hawking, Stephen
# 4                                   Orientalism        Said, Edward
# 5    Nature of Statistical Learning Theory, The    Vapnik, Vladimir
# 6              Integration of the Indian States          Menon, V P
# 7                          Drunkard's Walk, The   Mlodinow, Leonard
# ..                                          ...                 ...
# 206                    Structure and Randomness        Tao, Terence
# 207                Image Processing with MATLAB       Eddins, Steve
# 208                                 Animal Farm      Orwell, George
# 209                                  Idiot, The  Dostoevsky, Fyodor
# 210                          Christmas Carol, A    Dickens, Charles
#
#                  Genre  Height         Publisher
# 2          mathematics     197           Penguin
# 4              history     197           Penguin
# ...

# %%
cleaned_df = df.dropna()
cleaned_df
# Out:
#                                                  Title              Author  \
# 0                             Fundamentals of Wavelets    Goswami, Jaideva
# 1                                           Data Smart       Foreman, John
# 2                             God Created the Integers    Hawking, Stephen
# 3                                    Superfreakonomics     Dubner, Stephen
# 4                                          Orientalism        Said, Edward
# ..                                                 ...                 ...
# 115  Clash of Civilizations and Remaking of the Wor...  Huntington, Samuel
# 116                                    Uncommon Wisdom      Capra, Fritjof
# 117                                                One       Bach, Richard
# 119                                   To Sir With Love         Braithwaite
# 209                                         Idiot, The  Dostoevsky, Fyodor
#
#                  Genre  Height       Publisher
# ...

# %%
cleaned_df[cleaned_df["Genre"] == "history"].value_counts()
# Out:
# Title                                                   Author               Genre    Height  Publisher
# Orientalism                                             Said, Edward         history  197     Penguin             1
# Integration of the Indian States                        Menon, V P           history  217     Orient Blackswan    1
# Age of Wrath, The                                       Eraly, Abraham       history  238     Penguin             1
# All the President's Men                                 Woodward, Bob        history  177     Random House        1
# Scoop!                                                  Nayar, Kuldip        history  216     HarperCollins       1
# Last Mughal, The                                        Dalrymple, William   history  199     Penguin             1
# India from Midnight to Milennium                        Tharoor, Shashi      history  198     Penguin             1
# ...

# %%
cleaned_df.groupby("Genre").count()
# Out:
#                    Title  Author  Height  Publisher
# Genre
# computer_science       6       6       6          6
# data_science          11      11      11         11
# economics              9       9       9          9
# fiction               36      36      36         36
# history               12      12      12         12
# mathematics            3       3       3          3
# nonfiction            18      18      18         18
# philosophy             7       7       7          7
# psychology             1       1       1          1
# science                8       8       8          8
# signal_processing      2       2       2          2

# %%
cleaned_df.groupby("Height").max()
# Out:
#                                                   Title               Author  \
# Height
# 160                       Ashenden of The British Agent   Maugham, William S
# 167                                 Freedom at Midnight  Lapierre, Dominique
# 170                            Story of Philosophy, The         Durant, Will
# 171            Maugham's Collected Short Stories, Vol 3   Maugham, William S
# 172             Zen & The Art of Motorcycle Maintenance     Poe, Edgar Allen
# 174                                       Jurassic Park        Grisham, John
# 175                              Wealth of Nations, The      Steinbeck, John
# 176                                Prisoner of Birth, A         Follett, Ken
# 177                                        Veteran, The        Woodward, Bob
# 178                                       We the Living            Rand, Ayn
# 179                                 Tao of Physics, The     Stroud, Jonathan
# ...
